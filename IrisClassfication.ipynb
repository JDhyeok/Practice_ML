# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-b9bcd7523292> in <module>
#       6 model.add(Dense(3,activation='softmax'))
#       7
# ----> 8 model.compile(Adam(lr=0.04),'categorical_crossentropy',metrics=['accuracy'])
#       9
#      10 model.summary()
#
# c:\users\82109\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\keras\engine\training.py in compile(self, optimizer, loss, metrics, loss_weights, weighted_metrics, run_eagerly, **kwargs)
#     536     _keras_api_gauge.get_cell('compile').set(True)
#     537     with self.distribute_strategy.scope():
# --> 538       self._validate_compile(optimizer, metrics, **kwargs)
#     539       self._run_eagerly = run_eagerly
#     540
#
# c:\users\82109\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\keras\engine\training.py in _validate_compile(self, optimizer, metrics, **kwargs)
# ...
